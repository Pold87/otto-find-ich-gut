# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0.4, 0.95, 12)[::-1]

# %%
y = np.array([0.958333333333,
0.916666666667,
0.958333333333,
0.75,
0.958333333333,
0.75,
0.916666666667,
0.875,
0.958333333333,
0.916666666667,
1.04166666667,
1.04166666667])

# %%
plt.plot(x,y)
